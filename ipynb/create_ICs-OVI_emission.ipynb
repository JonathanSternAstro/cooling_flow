# %%
import sys, pdb
from importlib import reload
from astropy import units as un, constants as cons
from astropy.cosmology import Planck15 as cosmo
import numpy as np
from numpy import log10 as log
sys.path.append('../pysrc/')
import GIZMO_ICs as ics

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## steps
# * MakeDisk
#     * change parameters (e.g. resolution) in ../MakeDisk_wHalo_m11_lr/main.c
#     * compile with make
#     * run ./MakeHubbleType ICs/m11_no_halo_#vc#_res#2e4#_fgas#05#_Mdisk#1e10#.ic or
#     * ./MakeHubbleType ICs/m11_no_halo_#vc#_res#2e4#_fgas#05#_Rcirc#1#.ic if Rcirc!=10
#     * cp main.c to ICs/m11_no_halo_#vc#_res#2e4#_fgas#05#.main.c
# * create output files using script below

# %% [markdown]
# # example (simulation used in inflow paper)

# %%
reload(ics)
# Out:
# <module 'GIZMO_ICs' from '/mnt/home/jstern/cooling_flow/ipynb/../pysrc/GIZMO_ICs.py'>

# %%
Rcirc=6.*un.kpc
fiducial = ics.ICs(vc=100*un.km/un.s, #table 4 in Fraternali+11, at Rcirc
                   Rcirc=Rcirc, #R25 in Fraternali+18, max radius where HI is fit in non-tail side
                   Rsonic=0.5*un.kpc, #Mdot = 2  Msun/yr = SFR/2 where SFR=3.8 is from Popescu et al. (2004)
                   resolution = 1e3*un.Msun,
                    Z_CGM=0.1, #as Milky-Way
                   fgas=0.2)

# %%
fiducial.calc_CF_solution(pr=True)
ind = (fiducial.CF_solution.Rs()>20*un.kpc).nonzero()[0][0]
log_nH = log(fiducial.CF_solution.nHs()[ind].value)
print('log nH(20 kpc)=%.2f, Mdot=%.3f'%(log_nH,fiducial.CF_solution.Mdot.value))
# Out:
# Integrated with v_c^2/c_s^2 (R_sonic) =1.000010;  maximum r=10 kpc; stop reason: unbound
# Integrated with v_c^2/c_s^2 (R_sonic) =1.500005;  no transsonic solutions
# Integrated with v_c^2/c_s^2 (R_sonic) =1.250008;  maximum r=5 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.125009;  maximum r=32 kpc; stop reason: unbound
# Integrated with v_c^2/c_s^2 (R_sonic) =1.187508;  maximum r=659 kpc; stop reason: unbound
# Integrated with v_c^2/c_s^2 (R_sonic) =1.218758;  maximum r=19 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.203133;  maximum r=66 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.195321;  maximum r=221 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.191414;  maximum r=1004 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.189461;  maximum r=2230 kpc; stop reason: unbound
# Integrated with v_c^2/c_s^2 (R_sonic) =1.190438;  maximum r=2521 kpc; stop reason: sonic point
# Integrated with v_c^2/c_s^2 (R_sonic) =1.189950;  maximum r=9999 kpc; stop reason: max R reached
# Inward integration of supersonic part reached r = 0.300 kpc
# log nH(20 kpc)=-3.72, Mdot=0.446

# %%
fiducial.create_output_files()#'../MakeDisk_wHalo_m11_lr/ICs/m11_no_halo_100_res1e4_fgas02_Rcirc5.ic')
# Out:
# files saved to: /mnt/home/jstern/ceph/ICs/vc100_Rs0_Mdot445_Rcirc6_fgas02_res1e3
# ../MakeDisk_wHalo_m11_lr/ICs/m11_no_halo_100_res1e3_fgas02_Rcirc6.ic
#  2r(t_cool=10Gyr) = 140 kpc, r(t_sc=20Gyr) = 1792 kpc
# 0 [[-7.49826312e-01  8.20948601e-01  1.58403620e-01]
#  [ 4.03177500e+00  8.31581175e-01  3.12509276e-02]
#  [-1.72674730e-01 -2.78422952e+00 -8.65869671e-02]
#  ...
#  [-6.86803758e-01  1.46959329e+00 -9.59730670e-02]
#  [-1.21886921e+00  1.26836050e+00  3.79412268e-05]
#  [ 8.43279004e-01  1.74509203e+00 -1.12179004e-01]]
# Part0 num=14504862, w/o CGM=400000, |<r>|=0.1,0 [[ -79.64716339  -72.74698639    0.        ]
#  [ -22.72562981  110.18122864    0.        ]
#  [ 112.6031723    -6.98351955    0.        ]
#  ...
#  [-100.27242279  -46.86159134    0.        ]
#  [ -80.3516922   -77.21637726    0.        ]
#  [-100.34990692   48.49198151    0.        ]]
#  |<v>|=0.0, <j>=0.0 -0.1 397.6,0 [     1      2      3 ... 399998 399999 400000]
# max gas id: 14504861
# 0 [1.00000001e-07 1.00000001e-07 1.00000001e-07 ... 1.00000001e-07
#  1.00000001e-07 1.00000001e-07]
# Ms: 1e+03 1e+03 3e+03... 6.6e+06
# 1 []
# 1 []
# 1 []
# 1 []
# 2 [[-0.23549536 -0.48183694 -0.05184308]
#  [ 1.33673215 -1.3078258   0.0853776 ]
#  [-2.59295797  1.88191819 -0.04273099]
#  ...
#  [ 0.68260807  0.30975401 -0.0579661 ]
#  [ 0.86002493 -3.35238099  0.01584003]
#  [ 4.80714226 -2.02581167 -0.15925895]]
# Part2 num=2000000, |<r>|=0.0,2 [[109.86966705 -28.15574837  -4.72427511]
#  [ 95.66216278  70.21921539  -2.10887456]
#  [-65.95861816 -97.85699463   1.45633435]
#  ...
#  [-34.91702652 101.32112885  -4.49085569]
#  [108.50827026  24.36726761   5.30747366]
#  [ 44.5196228  100.89373016   5.05225182]]
#  |<v>|=0.1, <j>=-0.0 0.0 331.8,2 [ 400001  400002  400003 ... 2399998 2399999 2400000]
# 2 [1.00000001e-07 1.00000001e-07 1.00000001e-07 ... 1.00000001e-07
#  1.00000001e-07 1.00000001e-07]
# Ms: 1e+03
# 3 [[ 0.01619244  0.01852367 -0.0213889 ]
#  [-0.09408331  0.13249038 -0.03439589]
#  [ 0.29119936  0.22692037  0.0382515 ]
#  ...
#  [-0.0052668  -0.00309499  0.13735707]
#  [ 0.09087095  0.00436693  0.02678806]
#  [ 0.07917151 -0.00334163 -0.333536  ]]
# Part3 num=200000, |<r>|=0.0,3 [[  94.34685516  -97.91587067    2.20644188]
#  [  45.10877609   -4.32646656   98.67664337]
#  [  28.65368652 -141.15438843  -40.63354874]
#  ...
#  [  44.37956238  -22.16246414   25.37056732]
#  [ -30.00774574  -79.94211578   35.94881821]
#  [ -78.94562531  -23.81088638   10.84756374]]
#  |<v>|=0.3, <j>=0.9 0.1 0.7,3 [2400001 2400002 2400003 ... 2599998 2599999 2600000]
# 3 [1.00000001e-07 1.00000001e-07 1.00000001e-07 ... 1.00000001e-07
#  1.00000001e-07 1.00000001e-07]
# Ms: 1e+03
# 4 []
# 4 []
# 4 []
# 4 []
# 5 [[0. 0. 0.]]
# Part5 num=1, |<r>|=0.0,5 [[0. 0. 0.]]
#  |<v>|=0.0, <j>=0.0 0.0 0.0,5 [2600001]
# 5 [1.99999995e-05]
# Ms: 2e+05
# {'Npart': array([ 400000,       0, 2000000,  200000,       0,       1]), 'Mpart': array([0., 0., 0., 0., 0., 0.]), 'Time': 0.0, 'Ntot': 2600001}

# %% [markdown]
# # verification: plot integrated 1D solution

# %%
import pylab as pl
import matplotlib
import my_utils as u
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rc('font', family='serif', size=10)
matplotlib.rcParams['xtick.direction'] = 'in'
matplotlib.rcParams['ytick.direction'] = 'in'
matplotlib.rcParams['xtick.top'] = True
matplotlib.rcParams['ytick.right'] = True
fig_width_half = 3.4
figdir = '/Users/jonathanstern/Dropbox/github_repositories/gizmo_analysis/figures/'

# %%
fig = pl.figure(figsize=(10,7))
pl.subplots_adjust(hspace=0.3,wspace=0.4)
for iPanel in range(6):
    ax = pl.subplot(2,3,iPanel+1)
    for sol in [fiducial]:
        res = sol.CF_solution
        if iPanel==0: ys = res.Ts()
        if iPanel==1: ys = res.nHs()
        if iPanel==2: ys = res.Ms()
        if iPanel==3: ys = (res.t_cools() / (res.Rs()/res.vrs())).to('')
        if iPanel==4: ys = (res.Mgas()/sol.resolution)**(1/3.)
        if iPanel==5: ys = res.t_cools() 
        pl.loglog(res.Rs(),ys)
    pl.xlim(5,200)
    pl.xlabel(r'$r$ [kpc]')
    pl.axvline(Rcirc.value,c='.5',lw=0.5)
    ax.xaxis.set_major_formatter(u.arilogformatter)
    ax.yaxis.set_major_formatter(u.arilogformatter)
    if iPanel==0:
        pl.ylabel(r'temperature [K]')
        pl.ylim(0.5e4,3e7)
    if iPanel==1: 
        pl.ylabel(r'hydrogen density [cm$^{-3}$]')
        pl.ylim(1e-5,0.1)
    if iPanel==2: 
        pl.ylabel(r'mach number')
        pl.ylim(0.01,2)
        pl.axhline(1.,c='.5',lw=0.5)
    if iPanel==3: 
        pl.ylabel(r'$v_r / (r/t_{\rm cool})$')
        pl.ylim(0.03,3)
        pl.axhline(1.,c='.5',lw=0.5)
    if iPanel==4:
        pl.ylabel(r'$(M_{\rm gas}(<r) / {\rm resolution})^{1/3}$')
#         pl.ylim(0.03,3)
        pl.axhline(1.,c='.5',lw=0.5)
    if iPanel==5: 
        pl.plot(res.Rs(),res.tff().to('Gyr'),c='k')
        pl.ylabel(r'$t_{\rm cool}\ [{\rm Gyr}]$')
        pl.ylim(0.03,30)
        pl.axhline(1.,c='.5',lw=0.5)
#pl.savefig(figdir+'ICs_NGC891.pdf')

# %% [markdown]
# # verification: plot ICs snapshot

# %%
import h5py, scipy, scipy.stats, pylab as pl
from astropy import units as un, constants as cons
# %matplotlib inline
# instance = instances[0]
instance = fiducial #for Nadav's sims
init_snapshot_fn = instance.outdirname()+'/init_snapshot.hdf5'
init_snapshot = h5py.File(init_snapshot_fn,'r')

# %%
# disk only gas
snap = ics.gsr.Snapshot(instance.makedisk_filename())
coords = snap.SnapshotData['pos'][0]
energies = snap.SnapshotData['energies']
inds = (coords[:,1]<25) & (coords[:,1]>-25)
Xs = coords[:,0][inds]
Ys = coords[:,2][inds]
# vals = None #for counting stars
vals = energies[inds] * (un.km**2/un.s**2 * cons.m_p / cons.k_B).to('K').value * (2./3* 0.62)

# %%
# all gas
coords = init_snapshot['PartType0']['Coordinates']
vels = init_snapshot['PartType0']['Velocities']
inds = (coords[:,1]<5) & (coords[:,1]>-5)
Xs = coords[:,0][inds]
Zs = coords[:,2][inds]
# vals = None #for counting stars
# vals = init_snapshot['PartType0']['InternalEnergy'][inds] * (un.km**2/un.s**2 * cons.m_p / cons.k_B).to('K').value * (2./3* 0.62) 
phis = np.arctan2(vels[:,1][inds],vels[:,0][inds])

# %%
bins = (np.arange(-50,50,5),np.arange(-50,50,5))
m,x,y,_ = scipy.stats.binned_statistic_2d(Xs,
                                         Zs,
                                         vels[:,1][inds],
                                         statistic='median',
                                         bins=bins)
x = (x[1:]+x[:-1])/2; y = (y[1:]+y[:-1])/2;

# %%
pl.pcolormesh(x,y,m.T)
pl.colorbar(label = 'v_phi')
pl.xlabel('x [kpc]'); pl.ylabel('z [kpc]')
pl.title('all gas')
# pl.savefig(KY_path+'../figures/ICs_allgas_vphi.pdf')
# Out:
# Text(0.5, 1.0, 'all gas')

# %%
bins = (np.arange(-25,25,0.25),np.arange(-2.5,2.5,0.025))
m,x,y,_ = scipy.stats.binned_statistic_2d(Xs,
                                         Ys,
                                         None,
                                         statistic='count',
                                         bins=bins)
x = (x[1:]+x[:-1])/2; y = (y[1:]+y[:-1])/2;

# %%
pl.pcolormesh(x,y,m.T)
pl.colorbar(label = 'number of gas particles')
pl.xlabel('x [kpc]'); pl.ylabel('z [kpc]')
pl.title('gas -- disk only')
pl.savefig(KY_path+'../figures/ICs_gas_temperature.pdf')

# %%
coords = init_snapshot['PartType2']['Coordinates']
inds = (coords[:,1]<25) & (coords[:,1]>-25)
Xs = coords[:,0][inds]
Ys = coords[:,2][inds]

# %%
bins = (np.arange(-25,25,0.25),np.arange(-2.5,2.5,0.025))
m,x,y,_ = scipy.stats.binned_statistic_2d(Xs,
                                         Ys,
                                         None,
                                         statistic='count',
                                         bins=bins)
x = (x[1:]+x[:-1])/2; y = (y[1:]+y[:-1])/2;

# %%
pl.pcolormesh(x,y,m.T)
pl.colorbar(label = 'number of star particles per 0.25kpc x 0.025kpc')
pl.xlabel('x [kpc]'); pl.ylabel('z [kpc]')
pl.title('stars')
pl.savefig(KY_path+'../figures/stellar_locations.pdf')

# %%
pl.loglog(res.Rs(), res.Lambdas())
pl.ylim(1e-23,1e-22)
# Out:
# (1e-23, 1e-22)
